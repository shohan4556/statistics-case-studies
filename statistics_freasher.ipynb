# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 

print(np.__version__)
print(pd.__version__)
# Out:
# 1.18.1
# 1.0.1

# %% [markdown]
# ### Exponential distribution:
#
# 1. **Poisson process :** The timing of next event is completely independent of when the previous event happend.
# 2. The waiting between the arrival of Poisson process is exponentially distributed.

# %%
import stats as myst

#get random sample data 
data = np.random.exponential(0.50, 1000)
#calculate ecdf
x,y = myst._ecdf(data)
#plot the data
plt.plot(x,y, marker='.', linestyle='none')
plt.show()
